# %%
from IPython.display import display, clear_output
import time
import glob
from PIL import Image

# %%
from jyrobot.datasets import coil100, coil20
# Out:
# ...
# 1026995773440it [00:04, 225764618536.54it/s]
# ...
# 19066085376it [00:00, 29511672026.43it/s]

# %%
for degree in range(-720, 720):
    pic = coil20.get(1, degree)
    clear_output(wait=True)
    display(pic)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=128x128 at 0x7F8698CB6190>

# %%
for degree in range(-720,720):
    pic = coil100.get(1, degree)
    clear_output(wait=True)
    display(pic)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=128x128 at 0x7F8698CB68E0>

# %%
from ipycanvas import Canvas
c = Canvas(width=500, height=250)
c
# Out:
# Canvas(height=250, width=500)

# %%
c.put_image_data?
# Out:
# Signature: c.put_image_data(image_data, x=0, y=0)
# Docstring:
# Draw an image on the Canvas.
#
# ``image_data`` should be  a NumPy array containing the image to draw and ``x`` and ``y`` the pixel position where to
# draw. Unlike the CanvasRenderingContext2D.putImageData method, this method **is** affected by the canvas transformation
# matrix, and supports transparency.
# File:      ~/ipycanvas/ipycanvas/canvas.py
# Type:      method

# %%
import numpy as np

# %%
array = np.asarray(pic)

# %%
c.put_image_data(array, 10, 10)

# %%
from PIL import Image

# %%
image = Image.new("RGBA", (500, 250))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGBA size=500x250 at 0x7F8698CAD820>

# %%
image.paste(pic, (10, 10))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGBA size=500x250 at 0x7F8698CAD820>
